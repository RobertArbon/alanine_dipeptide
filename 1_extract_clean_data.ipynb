# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import re

# %%
trial_path = 'data/ala1_trials.csv'
df = pd.read_csv(trial_path)
df.T
# Out:
#                                                                 0    \
# id                                                                1
# project_name                                                    psi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.79617
# mean_train_score                                            1.80254
# train_scores      [1.7999580465973057, 1.819818978214972, 1.8121...
# test_scores       [1.7965262537904587, 1.7803040255062021, 1.787...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:06.985523
# completed                                2020-04-21 13:02:12.225977
# elapsed                                              0:07:05.240454
# host                                       compute497.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3239e17ea81a75b716cf568b127d6f14c8c7cdde
#
#                                                                 1    \
# id                                                                2
# project_name                                                   rmsd
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.70945
# mean_train_score                                            1.72172
# train_scores      [1.719747238300376, 1.7347387798970586, 1.7194...
# test_scores       [1.711065542152842, 1.7009932223203514, 1.7108...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:09.036900
# completed                                2020-04-21 13:27:55.889772
# elapsed                                              0:32:46.852872
# host                                       compute302.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                97a86e83aba004c989763cefbbbf885da174b06d
#
#                                                                 2    \
# id                                                                3
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.27758
# mean_train_score                                            3.31005
# train_scores      [3.414184993448893, 3.1504017903157893, 3.3170...
# test_scores       [3.2268539977212405, 3.373199437163835, 3.2931...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:10.956642
# completed                                2020-04-21 13:03:44.109700
# elapsed                                              0:08:33.153058
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
#
#                                                                 3    \
# id                                                                4
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.28763
# mean_train_score                                            3.29138
# train_scores      [3.3629736274675888, 3.2834543675750605, 3.122...
# test_scores       [3.237919527626562, 3.3144023635721327, 3.2747...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:10.958184
# completed                                2020-04-21 13:04:17.815297
# elapsed                                              0:09:06.857113
# host                                       compute298.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
#
#                                                                 4    \
# id                                                                5
# project_name                                                    phi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.98873
# mean_train_score                                            2.00986
# train_scores      [2.0134327673786805, 2.006846031785039, 2.0119...
# test_scores       [1.9866257740487083, 1.9868091417890301, 1.989...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:13.076849
# completed                                2020-04-21 13:17:47.361804
# elapsed                                              0:22:34.284955
# host                                       compute496.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3c2ba3a3d5e3b2fd171435e8801aab34f6bdde89
#
#                                                                 5    \
# id                                                                6
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.29336
# mean_train_score                                            3.33352
# train_scores      [3.43724230655605, 3.264923538558913, 3.372695...
# test_scores       [3.172532036892111, 3.3816289048732213, 3.2857...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:32.027129
# completed                                2020-04-21 13:25:30.217890
# elapsed                                              0:29:58.190761
# host                                       compute499.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
#
#                                                                 6    \
# id                                                                7
# project_name                                                   rmsd
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.70895
# mean_train_score                                             1.7282
# train_scores      [1.7269657197422499, 1.714271700353127, 1.7255...
# test_scores       [1.7103734897427463, 1.7189567616619494, 1.709...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:43.379275
# completed                                2020-04-21 13:39:50.676956
# elapsed                                              0:44:07.297681
# host                                       compute364.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                97a86e83aba004c989763cefbbbf885da174b06d
#
#                                                                 7    \
# id                                                                8
# project_name                                                    phi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.98758
# mean_train_score                                            1.99827
# train_scores      [1.9965219719365688, 1.9956206495454112, 2.002...
# test_scores       [1.9881758822146065, 1.9893494365498527, 1.987...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:43.905330
# completed                                2020-04-21 13:07:22.485168
# elapsed                                              0:11:38.579838
# host                                       compute364.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3c2ba3a3d5e3b2fd171435e8801aab34f6bdde89
#
#                                                                 8    \
# id                                                                9
# project_name                                                    psi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.79772
# mean_train_score                                            1.80197
# train_scores      [1.8157975850670391, 1.793250758600475, 1.8085...
# test_scores       [1.7843515963579788, 1.8037967878579375, 1.791...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:50.797260
# completed                                2020-04-21 13:01:06.019571
# elapsed                                              0:05:15.222311
# host                                       compute478.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3239e17ea81a75b716cf568b127d6f14c8c7cdde
#
#                                                                 9    ...  \
# id                                                               10  ...
# project_name                                              positions  ...
# status                                                    SUCCEEDED  ...
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...  ...
# mean_test_score                                             3.17429  ...
# mean_train_score                                            3.20034  ...
# train_scores      [3.2227773768488124, 3.2328996282007916, 3.302...  ...
# test_scores       [3.372651656675345, 3.312363186294038, 3.18628...  ...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...  ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...  ...
# started                                  2020-04-21 12:55:52.822308  ...
# completed                                2020-04-21 12:59:00.979932  ...
# elapsed                                              0:03:08.157624  ...
# host                                       compute478.bc4.acrc.priv  ...
# user                                                        ra15808  ...
# traceback                                                       NaN  ...
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784  ...
#
#                                                                 490  \
# id                                                              491
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                              3.3179
# mean_train_score                                            3.31388
# train_scores      [3.2610042136843083, 3.3326651038026456, 3.316...
# test_scores       [3.3730898146366495, 3.3365563984716546, 3.325...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:34:10.076393
# completed                                2020-04-22 03:58:06.645750
# elapsed                                              0:23:56.569357
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
#
#                                                                 491  \
# id                                                              492
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.30393
# mean_train_score                                            3.28656
# train_scores      [3.3389400336704127, 3.3058028353087794, 3.221...
# test_scores       [3.248556246903823, 3.3139944255527722, 3.3291...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:41:14.971949
# completed                                2020-04-22 03:53:19.326883
# elapsed                                              0:12:04.354934
# host                                       compute298.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
#
#                                                                 492  \
# id                                                              493
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.29895
# mean_train_score                                            3.36462
# train_scores      [3.3401960902086554, 3.3301608549864783, 3.417...
# test_scores       [3.332835880958976, 3.338076248789335, 3.28680...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:45:25.041988
# completed                                2020-04-22 04:32:33.535924
# elapsed                                              0:47:08.493936
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
#
#                                                                 493  \
# id                                                              494
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                              3.3274
# mean_train_score                                            3.29919
# train_scores      [3.312492371896006, 3.0710336983062083, 3.2342...
# test_scores       [3.3542086383520453, 3.33336397596106, 3.39959...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:58:06.718486
# completed                                2020-04-22 04:33:04.731127
# elapsed                                              0:34:58.012641
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
#
#                                                                 494  \
# id                                                              495
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.30535
# mean_train_score                                            3.34172
# train_scores      [3.3995519708522335, 3.408828272353943, 3.3676...
# test_scores       [3.29641047408263, 3.2177537004483376, 3.31852...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 04:32:33.636980
# completed                                2020-04-22 05:17:39.661727
# elapsed                                              0:45:06.024747
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
#
#                                                                 495  \
# id                                                              496
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.33471
# mean_train_score                                            3.33676
# train_scores      [3.1637566499946055, 3.3876221562489346, 3.386...
# test_scores       [3.41154857930344, 3.2805620739110797, 3.30155...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 04:33:04.826270
# completed                                2020-04-22 05:38:00.879794
# elapsed                                              1:04:56.053524
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
#
#                                                                 496  \
# id                                                              497
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.32041
# mean_train_score                                            3.29053
# train_scores      [3.1713173169768005, 3.28791071298196, 3.39049...
# test_scores       [3.3782417213892817, 3.332688705372567, 3.2536...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 05:17:39.755653
# completed                                2020-04-22 05:30:54.313718
# elapsed                                              0:13:14.558065
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
#
#                                                                 497  \
# id                                                              498
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             2.95912
# mean_train_score                                             2.9693
# train_scores      [2.7235869902028877, 3.216188202115833, 2.7281...
# test_scores       [2.722582568392066, 3.3171185759906088, 2.7155...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 05:38:00.960211
# completed                                2020-04-22 05:42:36.801511
# elapsed                                              0:04:35.841300
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
#
#                                                                 498  \
# id                                                              499
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.31295
# mean_train_score                                            3.33671
# train_scores      [3.2684733109324244, 3.373435632728065, 3.3913...
# test_scores       [3.396064728546611, 3.315277776903239, 3.26434...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 05:42:36.889252
# completed                                2020-04-22 06:36:45.637035
# elapsed                                              0:54:08.747783
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
#
#                                                                 499
# id                                                              500
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.09236
# mean_train_score                                            3.13082
# train_scores      [3.324926441506457, 2.730892463825786, 3.29652...
# test_scores       [3.2221693420757034, 2.7149465552752687, 3.258...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 06:36:45.724201
# completed                                2020-04-22 06:41:30.696467
# elapsed                                              0:04:44.972266
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
#
# [17 rows x 500 columns]

# %%
df['parameters'][0]
# Out:
# "{'cluster__skip': 0, 'cluster__init_strategy': 'kmeans++', 'msm__connectivity': 'largest', 'cluster__max_iter': 1000, 'cluster__stride': 10, 'cluster__keep_data': False, 'cluster__fixed_seed': 1577121803, 'msm__statdist_constraint': None, 'msm__sparse': False, 'cluster__oom_strategy': 'memmap', 'cluster__metric': 'euclidean', 'msm__score_method': 'VAMP2', 'msm__count_mode': 'sliding', 'msm__reversible': True, 'msm__maxiter': 1000000, 'msm__dt_traj': '1 step', 'msm__maxerr': 1e-08, 'cluster__n_clusters': 77, 'msm__lag': 9, 'cluster__tolerance': 1e-05, 'msm__mincount_connectivity': '1/n', 'cluster__n_jobs': 14, 'msm__score_k': 5}"

# %% [markdown]
# ## Summary statistics

# %%
def f(x, **kwargs):
    try: 
        y = re.findall('([0-9]\.[0-9]*)\,', str(x))
        y = [float(i) for i in y]
        g = kwargs.pop('stat')
        result = g(y, **kwargs)
    except:
        result = x
        
    return result
    
for col in ['test', 'train']:
    df.loc[:, col+'_mean'] = df[col+'_scores'].apply(f, stat=np.mean)
    df.loc[:, col+'_std'] =  df[col+'_scores'].apply(f, stat=np.std)
    df.loc[:, col+'_min'] =  df[col+'_scores'].apply(f, stat=np.min)
    df.loc[:, col+'_max'] =  df[col+'_scores'].apply(f, stat=np.max)
    df.loc[:, col+'_q25'] =  df[col+'_scores'].apply(f, stat=np.quantile, q=0.25)
    df.loc[:, col+'_q75'] =  df[col+'_scores'].apply(f, stat=np.quantile, q=0.75)

# %%
df.T
# Out:
#                                                                 0    \
# id                                                                1
# project_name                                                    psi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.79617
# mean_train_score                                            1.80254
# train_scores      [1.7999580465973057, 1.819818978214972, 1.8121...
# test_scores       [1.7965262537904587, 1.7803040255062021, 1.787...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:06.985523
# completed                                2020-04-21 13:02:12.225977
# elapsed                                              0:07:05.240454
# host                                       compute497.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3239e17ea81a75b716cf568b127d6f14c8c7cdde
# test_mean                                                   1.79637
# test_std                                                 0.00714649
# test_min                                                     1.7803
# test_max                                                    1.80753
# test_q25                                                    1.79344
# test_q75                                                    1.80171
# train_mean                                                  1.80233
# train_std                                                0.00762302
# train_min                                                   1.79146
# train_max                                                   1.81982
# train_q25                                                   1.79687
# train_q75                                                   1.80527
#
#                                                                 1    \
# id                                                                2
# project_name                                                   rmsd
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.70945
# mean_train_score                                            1.72172
# train_scores      [1.719747238300376, 1.7347387798970586, 1.7194...
# test_scores       [1.711065542152842, 1.7009932223203514, 1.7108...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:09.036900
# completed                                2020-04-21 13:27:55.889772
# elapsed                                              0:32:46.852872
# host                                       compute302.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                97a86e83aba004c989763cefbbbf885da174b06d
# test_mean                                                   1.70957
# test_std                                                 0.00393143
# test_min                                                    1.70099
# test_max                                                    1.71637
# test_q25                                                    1.70772
# test_q75                                                    1.71108
# train_mean                                                  1.72169
# train_std                                                0.00456037
# train_min                                                   1.71431
# train_max                                                   1.73474
# train_q25                                                   1.71925
# train_q75                                                   1.72364
#
#                                                                 2    \
# id                                                                3
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.27758
# mean_train_score                                            3.31005
# train_scores      [3.414184993448893, 3.1504017903157893, 3.3170...
# test_scores       [3.2268539977212405, 3.373199437163835, 3.2931...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:10.956642
# completed                                2020-04-21 13:03:44.109700
# elapsed                                              0:08:33.153058
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                   3.27798
# test_std                                                  0.0436926
# test_min                                                    3.19298
# test_max                                                     3.3732
# test_q25                                                    3.24749
# test_q75                                                      3.308
# train_mean                                                  3.30946
# train_std                                                 0.0651996
# train_min                                                    3.1504
# train_max                                                   3.41418
# train_q25                                                   3.29687
# train_q75                                                   3.34989
#
#                                                                 3    \
# id                                                                4
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.28763
# mean_train_score                                            3.29138
# train_scores      [3.3629736274675888, 3.2834543675750605, 3.122...
# test_scores       [3.237919527626562, 3.3144023635721327, 3.2747...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:10.958184
# completed                                2020-04-21 13:04:17.815297
# elapsed                                              0:09:06.857113
# host                                       compute298.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                   3.28693
# test_std                                                  0.0513389
# test_min                                                    3.16044
# test_max                                                    3.37626
# test_q25                                                    3.25512
# test_q75                                                    3.31306
# train_mean                                                  3.29057
# train_std                                                 0.0709483
# train_min                                                   3.09979
# train_max                                                   3.37539
# train_q25                                                   3.27782
# train_q75                                                   3.33162
#
#                                                                 4    \
# id                                                                5
# project_name                                                    phi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.98873
# mean_train_score                                            2.00986
# train_scores      [2.0134327673786805, 2.006846031785039, 2.0119...
# test_scores       [1.9866257740487083, 1.9868091417890301, 1.989...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:13.076849
# completed                                2020-04-21 13:17:47.361804
# elapsed                                              0:22:34.284955
# host                                       compute496.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3c2ba3a3d5e3b2fd171435e8801aab34f6bdde89
# test_mean                                                   1.98877
# test_std                                                 0.00171989
# test_min                                                    1.98408
# test_max                                                      1.991
# test_q25                                                    1.98798
# test_q75                                                    1.99029
# train_mean                                                  2.00965
# train_std                                                0.00351833
# train_min                                                    2.0051
# train_max                                                   2.01918
# train_q25                                                   2.00688
# train_q75                                                   2.01178
#
#                                                                 5    \
# id                                                                6
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.29336
# mean_train_score                                            3.33352
# train_scores      [3.43724230655605, 3.264923538558913, 3.372695...
# test_scores       [3.172532036892111, 3.3816289048732213, 3.2857...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:32.027129
# completed                                2020-04-21 13:25:30.217890
# elapsed                                              0:29:58.190761
# host                                       compute499.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                   3.29715
# test_std                                                  0.0666539
# test_min                                                    3.15869
# test_max                                                    3.40486
# test_q25                                                    3.24988
# test_q75                                                    3.33502
# train_mean                                                   3.3287
# train_std                                                 0.0843725
# train_min                                                   3.11782
# train_max                                                   3.43724
# train_q25                                                   3.30355
# train_q75                                                   3.38413
#
#                                                                 6    \
# id                                                                7
# project_name                                                   rmsd
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.70895
# mean_train_score                                             1.7282
# train_scores      [1.7269657197422499, 1.714271700353127, 1.7255...
# test_scores       [1.7103734897427463, 1.7189567616619494, 1.709...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:43.379275
# completed                                2020-04-21 13:39:50.676956
# elapsed                                              0:44:07.297681
# host                                       compute364.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                97a86e83aba004c989763cefbbbf885da174b06d
# test_mean                                                   1.70869
# test_std                                                 0.00584194
# test_min                                                    1.69626
# test_max                                                    1.71896
# test_q25                                                     1.7043
# test_q75                                                    1.71205
# train_mean                                                  1.72837
# train_std                                                 0.0076216
# train_min                                                   1.71427
# train_max                                                    1.7452
# train_q25                                                   1.72341
# train_q75                                                   1.73404
#
#                                                                 7    \
# id                                                                8
# project_name                                                    phi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.98758
# mean_train_score                                            1.99827
# train_scores      [1.9965219719365688, 1.9956206495454112, 2.002...
# test_scores       [1.9881758822146065, 1.9893494365498527, 1.987...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:43.905330
# completed                                2020-04-21 13:07:22.485168
# elapsed                                              0:11:38.579838
# host                                       compute364.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3c2ba3a3d5e3b2fd171435e8801aab34f6bdde89
# test_mean                                                   1.98756
# test_std                                                 0.00203539
# test_min                                                    1.98313
# test_max                                                    1.99075
# test_q25                                                    1.98662
# test_q75                                                    1.98901
# train_mean                                                  1.99841
# train_std                                                0.00242626
# train_min                                                   1.99462
# train_max                                                   2.00294
# train_q25                                                   1.99625
# train_q75                                                   2.00011
#
#                                                                 8    \
# id                                                                9
# project_name                                                    psi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             1.79772
# mean_train_score                                            1.80197
# train_scores      [1.8157975850670391, 1.793250758600475, 1.8085...
# test_scores       [1.7843515963579788, 1.8037967878579375, 1.791...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-21 12:55:50.797260
# completed                                2020-04-21 13:01:06.019571
# elapsed                                              0:05:15.222311
# host                                       compute478.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                3239e17ea81a75b716cf568b127d6f14c8c7cdde
# test_mean                                                   1.79831
# test_std                                                 0.00800736
# test_min                                                    1.78435
# test_max                                                    1.81717
# test_q25                                                    1.79245
# test_q75                                                    1.80376
# train_mean                                                  1.80133
# train_std                                                0.00846117
# train_min                                                   1.78116
# train_max                                                    1.8158
# train_q25                                                   1.79596
# train_q75                                                   1.80759
#
#                                                                 9    ...  \
# id                                                               10  ...
# project_name                                              positions  ...
# status                                                    SUCCEEDED  ...
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...  ...
# mean_test_score                                             3.17429  ...
# mean_train_score                                            3.20034  ...
# train_scores      [3.2227773768488124, 3.2328996282007916, 3.302...  ...
# test_scores       [3.372651656675345, 3.312363186294038, 3.18628...  ...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...  ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...  ...
# started                                  2020-04-21 12:55:52.822308  ...
# completed                                2020-04-21 12:59:00.979932  ...
# elapsed                                              0:03:08.157624  ...
# host                                       compute478.bc4.acrc.priv  ...
# user                                                        ra15808  ...
# traceback                                                       NaN  ...
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784  ...
# test_mean                                                   3.16998  ...
# test_std                                                   0.211082  ...
# test_min                                                    2.71624  ...
# test_max                                                    3.37265  ...
# test_q25                                                    3.13314  ...
# test_q75                                                    3.31836  ...
# train_mean                                                  3.19286  ...
# train_std                                                  0.211487  ...
# train_min                                                   2.72749  ...
# train_max                                                   3.37817  ...
# train_q25                                                   3.17611  ...
# train_q75                                                   3.33655  ...
#
#                                                                 490  \
# id                                                              491
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                              3.3179
# mean_train_score                                            3.31388
# train_scores      [3.2610042136843083, 3.3326651038026456, 3.316...
# test_scores       [3.3730898146366495, 3.3365563984716546, 3.325...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:34:10.076393
# completed                                2020-04-22 03:58:06.645750
# elapsed                                              0:23:56.569357
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                   3.31788
# test_std                                                  0.0422217
# test_min                                                    3.23759
# test_max                                                    3.40963
# test_q25                                                    3.28727
# test_q75                                                    3.34716
# train_mean                                                  3.31322
# train_std                                                 0.0769738
# train_min                                                   3.08967
# train_max                                                   3.41088
# train_q25                                                   3.30783
# train_q75                                                   3.34501
#
#                                                                 491  \
# id                                                              492
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.30393
# mean_train_score                                            3.28656
# train_scores      [3.3389400336704127, 3.3058028353087794, 3.221...
# test_scores       [3.248556246903823, 3.3139944255527722, 3.3291...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:41:14.971949
# completed                                2020-04-22 03:53:19.326883
# elapsed                                              0:12:04.354934
# host                                       compute298.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                   3.30056
# test_std                                                  0.0537668
# test_min                                                    3.18678
# test_max                                                     3.4155
# test_q25                                                    3.27425
# test_q75                                                    3.32844
# train_mean                                                  3.28922
# train_std                                                  0.076554
# train_min                                                   3.10008
# train_max                                                   3.41958
# train_q25                                                   3.26239
# train_q75                                                   3.32792
#
#                                                                 492  \
# id                                                              493
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.29895
# mean_train_score                                            3.36462
# train_scores      [3.3401960902086554, 3.3301608549864783, 3.417...
# test_scores       [3.332835880958976, 3.338076248789335, 3.28680...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:45:25.041988
# completed                                2020-04-22 04:32:33.535924
# elapsed                                              0:47:08.493936
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                   3.29722
# test_std                                                   0.044132
# test_min                                                     3.2018
# test_max                                                    3.38594
# test_q25                                                     3.2649
# test_q75                                                    3.33013
# train_mean                                                  3.36847
# train_std                                                 0.0703004
# train_min                                                    3.2475
# train_max                                                   3.48764
# train_q25                                                   3.32583
# train_q75                                                   3.41471
#
#                                                                 493  \
# id                                                              494
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                              3.3274
# mean_train_score                                            3.29919
# train_scores      [3.312492371896006, 3.0710336983062083, 3.2342...
# test_scores       [3.3542086383520453, 3.33336397596106, 3.39959...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 03:58:06.718486
# completed                                2020-04-22 04:33:04.731127
# elapsed                                              0:34:58.012641
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                   3.32348
# test_std                                                  0.0702024
# test_min                                                     3.1384
# test_max                                                    3.41031
# test_q25                                                    3.28077
# test_q75                                                    3.37418
# train_mean                                                  3.30073
# train_std                                                 0.0915054
# train_min                                                   3.07103
# train_max                                                   3.45345
# train_q25                                                   3.23466
# train_q75                                                   3.36942
#
#                                                                 494  \
# id                                                              495
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.30535
# mean_train_score                                            3.34172
# train_scores      [3.3995519708522335, 3.408828272353943, 3.3676...
# test_scores       [3.29641047408263, 3.2177537004483376, 3.31852...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 04:32:33.636980
# completed                                2020-04-22 05:17:39.661727
# elapsed                                              0:45:06.024747
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                   3.29749
# test_std                                                  0.0619011
# test_min                                                    3.17435
# test_max                                                    3.38615
# test_q25                                                    3.25526
# test_q75                                                    3.36138
# train_mean                                                  3.34543
# train_std                                                 0.0813219
# train_min                                                   3.10692
# train_max                                                   3.44401
# train_q25                                                   3.30775
# train_q75                                                   3.40419
#
#                                                                 495  \
# id                                                              496
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.33471
# mean_train_score                                            3.33676
# train_scores      [3.1637566499946055, 3.3876221562489346, 3.386...
# test_scores       [3.41154857930344, 3.2805620739110797, 3.30155...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 04:33:04.826270
# completed                                2020-04-22 05:38:00.879794
# elapsed                                              1:04:56.053524
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                   3.33242
# test_std                                                  0.0538308
# test_min                                                    3.20591
# test_max                                                    3.41563
# test_q25                                                    3.29958
# test_q75                                                    3.37557
# train_mean                                                  3.33837
# train_std                                                 0.0670039
# train_min                                                   3.16376
# train_max                                                   3.46216
# train_q25                                                   3.29623
# train_q75                                                   3.37666
#
#                                                                 496  \
# id                                                              497
# project_name                                                 phipsi
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.32041
# mean_train_score                                            3.29053
# train_scores      [3.1713173169768005, 3.28791071298196, 3.39049...
# test_scores       [3.3782417213892817, 3.332688705372567, 3.2536...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 05:17:39.755653
# completed                                2020-04-22 05:30:54.313718
# elapsed                                              0:13:14.558065
# host                                       compute508.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                   3.31647
# test_std                                                   0.050909
# test_min                                                    3.21655
# test_max                                                    3.39676
# test_q25                                                    3.28835
# test_q75                                                     3.3481
# train_mean                                                  3.29686
# train_std                                                 0.0641589
# train_min                                                   3.17132
# train_max                                                    3.3905
# train_q25                                                   3.26153
# train_q75                                                   3.34437
#
#                                                                 497  \
# id                                                              498
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             2.95912
# mean_train_score                                             2.9693
# train_scores      [2.7235869902028877, 3.216188202115833, 2.7281...
# test_scores       [2.722582568392066, 3.3171185759906088, 2.7155...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 05:38:00.960211
# completed                                2020-04-22 05:42:36.801511
# elapsed                                              0:04:35.841300
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                   2.94608
# test_std                                                   0.272425
# test_min                                                     2.7146
# test_max                                                    3.32951
# test_q25                                                    2.71858
# test_q75                                                    3.29003
# train_mean                                                  2.95152
# train_std                                                  0.267147
# train_min                                                   2.71496
# train_max                                                   3.34277
# train_q25                                                    2.7258
# train_q75                                                   3.23227
#
#                                                                 498  \
# id                                                              499
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.31295
# mean_train_score                                            3.33671
# train_scores      [3.2684733109324244, 3.373435632728065, 3.3913...
# test_scores       [3.396064728546611, 3.315277776903239, 3.26434...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 05:42:36.889252
# completed                                2020-04-22 06:36:45.637035
# elapsed                                              0:54:08.747783
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                   3.31237
# test_std                                                  0.0631367
# test_min                                                    3.14959
# test_max                                                    3.39606
# test_q25                                                    3.27834
# test_q75                                                    3.35334
# train_mean                                                   3.3358
# train_std                                                 0.0898372
# train_min                                                   3.05156
# train_max                                                   3.47122
# train_q25                                                   3.30078
# train_q75                                                   3.38238
#
#                                                                 499
# id                                                              500
# project_name                                              positions
# status                                                    SUCCEEDED
# parameters        {'cluster__skip': 0, 'cluster__init_strategy':...
# mean_test_score                                             3.09236
# mean_train_score                                            3.13082
# train_scores      [3.324926441506457, 2.730892463825786, 3.29652...
# test_scores       [3.2221693420757034, 2.7149465552752687, 3.258...
# n_train_samples   [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples    [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                  2020-04-22 06:36:45.724201
# completed                                2020-04-22 06:41:30.696467
# elapsed                                              0:04:44.972266
# host                                       compute229.bc4.acrc.priv
# user                                                        ra15808
# traceback                                                       NaN
# config_sha1                94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                   3.08385
# test_std                                                   0.248147
# test_min                                                    2.71495
# test_max                                                    3.34492
# test_q25                                                    2.72731
# test_q75                                                     3.2587
# train_mean                                                  3.12153
# train_std                                                  0.272889
# train_min                                                   2.71773
# train_max                                                   3.38883
# train_q25                                                   2.72797
# train_q75                                                   3.31887
#
# [29 rows x 500 columns]

# %% [markdown]
# ## Parameters

# %%
def get_dict(x):
    return dict(re.findall("'(.*?)'\: (.*?)[,\}]", x))

df.loc[:, 'parameters'] = df['parameters'].apply(get_dict)

# %%
keys = list(df['parameters'][0].keys())
for k in keys: 
    df.loc[:, k] = df['parameters'].apply(lambda x: x[k])

# %%
for k in keys:
    try:
        df.loc[:, k] = df.loc[:, k].astype(float)
    except ValueError: 
        df.loc[:, k] = df.loc[:, k].astype("category")

# %%
df.T
# Out:
#                                                                           0    \
# id                                                                          1
# project_name                                                              psi
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       1.79617
# mean_train_score                                                      1.80254
# train_scores                [1.7999580465973057, 1.819818978214972, 1.8121...
# test_scores                 [1.7965262537904587, 1.7803040255062021, 1.787...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:06.985523
# completed                                          2020-04-21 13:02:12.225977
# elapsed                                                        0:07:05.240454
# host                                                 compute497.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          3239e17ea81a75b716cf568b127d6f14c8c7cdde
# test_mean                                                             1.79637
# test_std                                                           0.00714649
# test_min                                                               1.7803
# test_max                                                              1.80753
# test_q25                                                              1.79344
# test_q75                                                              1.80171
# train_mean                                                            1.80233
# train_std                                                          0.00762302
# train_min                                                             1.79146
# train_max                                                             1.81982
# train_q25                                                             1.79687
# train_q75                                                             1.80527
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               1.57712e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                        77
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           1    \
# id                                                                          2
# project_name                                                             rmsd
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       1.70945
# mean_train_score                                                      1.72172
# train_scores                [1.719747238300376, 1.7347387798970586, 1.7194...
# test_scores                 [1.711065542152842, 1.7009932223203514, 1.7108...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:09.036900
# completed                                          2020-04-21 13:27:55.889772
# elapsed                                                        0:32:46.852872
# host                                                 compute302.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          97a86e83aba004c989763cefbbbf885da174b06d
# test_mean                                                             1.70957
# test_std                                                           0.00393143
# test_min                                                              1.70099
# test_max                                                              1.71637
# test_q25                                                              1.70772
# test_q75                                                              1.71108
# train_mean                                                            1.72169
# train_std                                                          0.00456037
# train_min                                                             1.71431
# train_max                                                             1.73474
# train_q25                                                             1.71925
# train_q75                                                             1.72364
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               3.68067e+08
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                       554
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           2    \
# id                                                                          3
# project_name                                                           phipsi
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       3.27758
# mean_train_score                                                      3.31005
# train_scores                [3.414184993448893, 3.1504017903157893, 3.3170...
# test_scores                 [3.2268539977212405, 3.373199437163835, 3.2931...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:10.956642
# completed                                          2020-04-21 13:03:44.109700
# elapsed                                                        0:08:33.153058
# host                                                 compute508.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                             3.27798
# test_std                                                            0.0436926
# test_min                                                              3.19298
# test_max                                                               3.3732
# test_q25                                                              3.24749
# test_q75                                                                3.308
# train_mean                                                            3.30946
# train_std                                                           0.0651996
# train_min                                                              3.1504
# train_max                                                             3.41418
# train_q25                                                             3.29687
# train_q75                                                             3.34989
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               4.37559e+08
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                        97
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           3    \
# id                                                                          4
# project_name                                                           phipsi
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       3.28763
# mean_train_score                                                      3.29138
# train_scores                [3.3629736274675888, 3.2834543675750605, 3.122...
# test_scores                 [3.237919527626562, 3.3144023635721327, 3.2747...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:10.958184
# completed                                          2020-04-21 13:04:17.815297
# elapsed                                                        0:09:06.857113
# host                                                 compute298.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                             3.28693
# test_std                                                            0.0513389
# test_min                                                              3.16044
# test_max                                                              3.37626
# test_q25                                                              3.25512
# test_q75                                                              3.31306
# train_mean                                                            3.29057
# train_std                                                           0.0709483
# train_min                                                             3.09979
# train_max                                                             3.37539
# train_q25                                                             3.27782
# train_q75                                                             3.33162
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               4.06614e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                        95
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           4    \
# id                                                                          5
# project_name                                                              phi
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       1.98873
# mean_train_score                                                      2.00986
# train_scores                [2.0134327673786805, 2.006846031785039, 2.0119...
# test_scores                 [1.9866257740487083, 1.9868091417890301, 1.989...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:13.076849
# completed                                          2020-04-21 13:17:47.361804
# elapsed                                                        0:22:34.284955
# host                                                 compute496.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          3c2ba3a3d5e3b2fd171435e8801aab34f6bdde89
# test_mean                                                             1.98877
# test_std                                                           0.00171989
# test_min                                                              1.98408
# test_max                                                                1.991
# test_q25                                                              1.98798
# test_q75                                                              1.99029
# train_mean                                                            2.00965
# train_std                                                          0.00351833
# train_min                                                              2.0051
# train_max                                                             2.01918
# train_q25                                                             2.00688
# train_q75                                                             2.01178
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               3.87442e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                       362
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           5    \
# id                                                                          6
# project_name                                                        positions
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       3.29336
# mean_train_score                                                      3.33352
# train_scores                [3.43724230655605, 3.264923538558913, 3.372695...
# test_scores                 [3.172532036892111, 3.3816289048732213, 3.2857...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:32.027129
# completed                                          2020-04-21 13:25:30.217890
# elapsed                                                        0:29:58.190761
# host                                                 compute499.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                             3.29715
# test_std                                                            0.0666539
# test_min                                                              3.15869
# test_max                                                              3.40486
# test_q25                                                              3.24988
# test_q75                                                              3.33502
# train_mean                                                             3.3287
# train_std                                                           0.0843725
# train_min                                                             3.11782
# train_max                                                             3.43724
# train_q25                                                             3.30355
# train_q75                                                             3.38413
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               3.80677e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                       440
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           6    \
# id                                                                          7
# project_name                                                             rmsd
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       1.70895
# mean_train_score                                                       1.7282
# train_scores                [1.7269657197422499, 1.714271700353127, 1.7255...
# test_scores                 [1.7103734897427463, 1.7189567616619494, 1.709...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:43.379275
# completed                                          2020-04-21 13:39:50.676956
# elapsed                                                        0:44:07.297681
# host                                                 compute364.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          97a86e83aba004c989763cefbbbf885da174b06d
# test_mean                                                             1.70869
# test_std                                                           0.00584194
# test_min                                                              1.69626
# test_max                                                              1.71896
# test_q25                                                               1.7043
# test_q75                                                              1.71205
# train_mean                                                            1.72837
# train_std                                                           0.0076216
# train_min                                                             1.71427
# train_max                                                              1.7452
# train_q25                                                             1.72341
# train_q75                                                             1.73404
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               1.68589e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                       942
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           7    \
# id                                                                          8
# project_name                                                              phi
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       1.98758
# mean_train_score                                                      1.99827
# train_scores                [1.9965219719365688, 1.9956206495454112, 2.002...
# test_scores                 [1.9881758822146065, 1.9893494365498527, 1.987...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:43.905330
# completed                                          2020-04-21 13:07:22.485168
# elapsed                                                        0:11:38.579838
# host                                                 compute364.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          3c2ba3a3d5e3b2fd171435e8801aab34f6bdde89
# test_mean                                                             1.98756
# test_std                                                           0.00203539
# test_min                                                              1.98313
# test_max                                                              1.99075
# test_q25                                                              1.98662
# test_q75                                                              1.98901
# train_mean                                                            1.99841
# train_std                                                          0.00242626
# train_min                                                             1.99462
# train_max                                                             2.00294
# train_q25                                                             1.99625
# train_q75                                                             2.00011
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               1.91113e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                       169
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           8    \
# id                                                                          9
# project_name                                                              psi
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       1.79772
# mean_train_score                                                      1.80197
# train_scores                [1.8157975850670391, 1.793250758600475, 1.8085...
# test_scores                 [1.7843515963579788, 1.8037967878579375, 1.791...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:50.797260
# completed                                          2020-04-21 13:01:06.019571
# elapsed                                                        0:05:15.222311
# host                                                 compute478.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          3239e17ea81a75b716cf568b127d6f14c8c7cdde
# test_mean                                                             1.79831
# test_std                                                           0.00800736
# test_min                                                              1.78435
# test_max                                                              1.81717
# test_q25                                                              1.79245
# test_q75                                                              1.80376
# train_mean                                                            1.80133
# train_std                                                          0.00846117
# train_min                                                             1.78116
# train_max                                                              1.8158
# train_q25                                                             1.79596
# train_q75                                                             1.80759
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                                2.2562e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                        96
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           9    \
# id                                                                         10
# project_name                                                        positions
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       3.17429
# mean_train_score                                                      3.20034
# train_scores                [3.2227773768488124, 3.2328996282007916, 3.302...
# test_scores                 [3.372651656675345, 3.312363186294038, 3.18628...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-21 12:55:52.822308
# completed                                          2020-04-21 12:59:00.979932
# elapsed                                                        0:03:08.157624
# host                                                 compute478.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                             3.16998
# test_std                                                             0.211082
# test_min                                                              2.71624
# test_max                                                              3.37265
# test_q25                                                              3.13314
# test_q75                                                              3.31836
# train_mean                                                            3.19286
# train_std                                                            0.211487
# train_min                                                             2.72749
# train_max                                                             3.37817
# train_q25                                                             3.17611
# train_q75                                                             3.33655
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               8.48397e+08
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                        33
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                             ...  \
# id                          ...
# project_name                ...
# status                      ...
# parameters                  ...
# mean_test_score             ...
# mean_train_score            ...
# train_scores                ...
# test_scores                 ...
# n_train_samples             ...
# n_test_samples              ...
# started                     ...
# completed                   ...
# elapsed                     ...
# host                        ...
# user                        ...
# traceback                   ...
# config_sha1                 ...
# test_mean                   ...
# test_std                    ...
# test_min                    ...
# test_max                    ...
# test_q25                    ...
# test_q75                    ...
# train_mean                  ...
# train_std                   ...
# train_min                   ...
# train_max                   ...
# train_q25                   ...
# train_q75                   ...
# cluster__skip               ...
# cluster__init_strategy      ...
# msm__connectivity           ...
# cluster__max_iter           ...
# cluster__stride             ...
# cluster__keep_data          ...
# cluster__fixed_seed         ...
# msm__statdist_constraint    ...
# msm__sparse                 ...
# cluster__oom_strategy       ...
# cluster__metric             ...
# msm__score_method           ...
# msm__count_mode             ...
# msm__reversible             ...
# msm__maxiter                ...
# msm__dt_traj                ...
# msm__maxerr                 ...
# cluster__n_clusters         ...
# msm__lag                    ...
# cluster__tolerance          ...
# msm__mincount_connectivity  ...
# cluster__n_jobs             ...
# msm__score_k                ...
#
#                                                                           490  \
# id                                                                        491
# project_name                                                        positions
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                        3.3179
# mean_train_score                                                      3.31388
# train_scores                [3.2610042136843083, 3.3326651038026456, 3.316...
# test_scores                 [3.3730898146366495, 3.3365563984716546, 3.325...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-22 03:34:10.076393
# completed                                          2020-04-22 03:58:06.645750
# elapsed                                                        0:23:56.569357
# host                                                 compute229.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                             3.31788
# test_std                                                            0.0422217
# test_min                                                              3.23759
# test_max                                                              3.40963
# test_q25                                                              3.28727
# test_q75                                                              3.34716
# train_mean                                                            3.31322
# train_std                                                           0.0769738
# train_min                                                             3.08967
# train_max                                                             3.41088
# train_q25                                                             3.30783
# train_q75                                                             3.34501
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               2.50978e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# ...
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          b2381ac7618996d19d4c7b0447d234c7c4c86251
# test_mean                                                             3.31647
# test_std                                                             0.050909
# test_min                                                              3.21655
# test_max                                                              3.39676
# test_q25                                                              3.28835
# test_q75                                                               3.3481
# train_mean                                                            3.29686
# train_std                                                           0.0641589
# train_min                                                             3.17132
# train_max                                                              3.3905
# train_q25                                                             3.26153
# train_q75                                                             3.34437
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               4.37559e+08
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                       169
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           497  \
# id                                                                        498
# project_name                                                        positions
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       2.95912
# mean_train_score                                                       2.9693
# train_scores                [2.7235869902028877, 3.216188202115833, 2.7281...
# test_scores                 [2.722582568392066, 3.3171185759906088, 2.7155...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-22 05:38:00.960211
# completed                                          2020-04-22 05:42:36.801511
# elapsed                                                        0:04:35.841300
# host                                                 compute229.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                             2.94608
# test_std                                                             0.272425
# test_min                                                               2.7146
# test_max                                                              3.32951
# test_q25                                                              2.71858
# test_q75                                                              3.29003
# train_mean                                                            2.95152
# train_std                                                            0.267147
# train_min                                                             2.71496
# train_max                                                             3.34277
# train_q25                                                              2.7258
# train_q75                                                             3.23227
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               2.50978e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                        23
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           498  \
# id                                                                        499
# project_name                                                        positions
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       3.31295
# mean_train_score                                                      3.33671
# train_scores                [3.2684733109324244, 3.373435632728065, 3.3913...
# test_scores                 [3.396064728546611, 3.315277776903239, 3.26434...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-22 05:42:36.889252
# completed                                          2020-04-22 06:36:45.637035
# elapsed                                                        0:54:08.747783
# host                                                 compute229.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                             3.31237
# test_std                                                            0.0631367
# test_min                                                              3.14959
# test_max                                                              3.39606
# test_q25                                                              3.27834
# test_q75                                                              3.35334
# train_mean                                                             3.3358
# train_std                                                           0.0898372
# train_min                                                             3.05156
# train_max                                                             3.47122
# train_q25                                                             3.30078
# train_q75                                                             3.38238
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               2.50978e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                       763
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
#                                                                           499
# id                                                                        500
# project_name                                                        positions
# status                                                              SUCCEEDED
# parameters                  {'cluster__skip': '0', 'cluster__init_strategy...
# mean_test_score                                                       3.09236
# mean_train_score                                                      3.13082
# train_scores                [3.324926441506457, 2.730892463825786, 3.29652...
# test_scores                 [3.2221693420757034, 2.7149465552752687, 3.258...
# n_train_samples             [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# n_test_samples              [375, 375, 375, 375, 375, 375, 375, 375, 375, ...
# started                                            2020-04-22 06:36:45.724201
# completed                                          2020-04-22 06:41:30.696467
# elapsed                                                        0:04:44.972266
# host                                                 compute229.bc4.acrc.priv
# user                                                                  ra15808
# traceback                                                                 NaN
# config_sha1                          94b1173bdb31956b552f8bd16deb6213dbe37784
# test_mean                                                             3.08385
# test_std                                                             0.248147
# test_min                                                              2.71495
# test_max                                                              3.34492
# test_q25                                                              2.72731
# test_q75                                                               3.2587
# train_mean                                                            3.12153
# train_std                                                            0.272889
# train_min                                                             2.71773
# train_max                                                             3.38883
# train_q25                                                             2.72797
# train_q75                                                             3.31887
# cluster__skip                                                               0
# cluster__init_strategy                                             'kmeans++'
# msm__connectivity                                                   'largest'
# cluster__max_iter                                                        1000
# cluster__stride                                                            10
# cluster__keep_data                                                      False
# cluster__fixed_seed                                               2.50978e+09
# msm__statdist_constraint                                                 None
# msm__sparse                                                             False
# cluster__oom_strategy                                                'memmap'
# cluster__metric                                                   'euclidean'
# msm__score_method                                                     'VAMP2'
# msm__count_mode                                                     'sliding'
# msm__reversible                                                          True
# msm__maxiter                                                            1e+06
# msm__dt_traj                                                         '1 step'
# msm__maxerr                                                             1e-08
# cluster__n_clusters                                                        29
# msm__lag                                                                    9
# cluster__tolerance                                                      1e-05
# msm__mincount_connectivity                                              '1/n'
# cluster__n_jobs                                                            14
# msm__score_k                                                                5
#
# [52 rows x 500 columns]

# %% [markdown]
# ## Drop redundant columns

# %%
df.drop(columns=['mean_test_score', 'mean_train_score'], inplace=True)

# %% [markdown]
# ## Missing values

# %%
df.isna().sum(axis=0)
# Out:
# id                              0
# project_name                    0
# status                          0
# parameters                      0
# train_scores                    0
# test_scores                     0
# n_train_samples                 0
# n_test_samples                  0
# started                         0
# completed                       0
# elapsed                         0
# host                            0
# user                            0
# traceback                     500
# config_sha1                     0
# test_mean                       0
# test_std                        0
# test_min                        0
# test_max                        0
# test_q25                        0
# test_q75                        0
# train_mean                      0
# train_std                       0
# train_min                       0
# train_max                       0
# train_q25                       0
# train_q75                       0
# cluster__skip                   0
# cluster__init_strategy          0
# msm__connectivity               0
# cluster__max_iter               0
# cluster__stride                 0
# cluster__keep_data              0
# cluster__fixed_seed             0
# msm__statdist_constraint        0
# msm__sparse                     0
# cluster__oom_strategy           0
# cluster__metric                 0
# msm__score_method               0
# msm__count_mode                 0
# msm__reversible                 0
# msm__maxiter                    0
# msm__dt_traj                    0
# msm__maxerr                     0
# cluster__n_clusters             0
# msm__lag                        0
# cluster__tolerance              0
# msm__mincount_connectivity      0
# cluster__n_jobs                 0
# msm__score_k                    0
# dtype: int64

# %%
df.loc[df['completed'].isna(), :].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [id, project_name, status, parameters, train_scores, test_scores, n_train_samples, n_test_samples, started, completed, elapsed, host, user, traceback, config_sha1, test_mean, test_std, test_min, test_max, test_q25, test_q75, train_mean, train_std, train_min, train_max, train_q25, train_q75, cluster__skip, cluster__init_strategy, msm__connectivity, cluster__max_iter, cluster__stride, cluster__keep_data, cluster__fixed_seed, msm__statdist_constraint, msm__sparse, cluster__oom_strategy, cluster__metric, msm__score_method, msm__count_mode, msm__reversible, msm__maxiter, msm__dt_traj, msm__maxerr, cluster__n_clusters, msm__lag, cluster__tolerance, msm__mincount_connectivity, cluster__n_jobs, msm__score_k]

# %%
print(df.shape)
df = df.loc[df['status']=='SUCCEEDED', : ]
df = df.drop(columns='traceback')
print(df.shape)
# Out:
# (500, 50)
# (500, 49)

# %% [markdown]
# ## Save data

# %%
from pathlib import PurePath

out_path = str(PurePath('outputs').joinpath(PurePath(trial_path).name))
out_path = out_path.replace('.csv', '_clean.csv')

df.to_csv(out_path,index=False)
